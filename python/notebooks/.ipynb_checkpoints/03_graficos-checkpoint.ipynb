# %%
import matplotlib.pyplot as plt

# %%
plt.plot([2.5,3.8,4.8,5.2],[1, 2, 3, 4])
plt.ylabel('números')
# plt.axis([0,6.0,0,5.0])
plt.show()

# %%
cursos = ['1415', '1516', '1617', '1718', '1819']
aprovats = [22,25,28,29,31]
plt.plot(cursos,aprovats)
plt.xlabel('cursos')
plt.ylabel('aprovats i aprovades')
plt.show()

# %%
cursos = ['1415', '1516', '1617', '1718', '1819']
aprovats = [22,25,28,29,31]
dades = plt.plot(cursos,aprovats)
plt.xlabel('cursos')
plt.ylabel('aprovats i aprovades')
plt.setp(dades, color='red', linewidth=2.5)
plt.show()

# %%
cursos = ['1415', '1516', '1617', '1718', '1819']
aprovats = [22,25,28,29,31]
plt.bar(cursos,aprovats)
plt.xlabel('cursos')
plt.ylabel('aprovats i aprovades')
plt.show()

# %%
cursos = ['1415', '1516', '1617', '1718', '1819']
aprovats = [22,25,28,29,31]
# plt.bar(cursos,aprovats)
plt.bar(cursos,aprovats, color='red', width=0.5, edgecolor='green', linewidth=2.0)
plt.xlabel('cursos')
plt.ylabel('aprovats i aprovades')
plt.show()

# %%
cursos = ['1415', '1516', '1617', '1718', '1819']
aprovats = [22,25,28,29,31]
plt.barh(cursos,aprovats, color='red', height=0.5, edgecolor='green', linewidth=2.0)
plt.title('Aprovats vs cursos')
plt.xlabel('aprovats i aprovades')
plt.ylabel('cursos')
plt.show()

# %%
cursos = ['1415', '1516', '1617', '1718', '1819']
aprovats = [22,25,28,29,31]
dades = plt.scatter(cursos,aprovats)
plt.xlabel('cursos')
plt.ylabel('aprovats i aprovades')
plt.setp(dades, color='red', linewidth=2.5)
plt.show()

# %%
cursos = ['1415', '1516', '1617', '1718', '1819']
aprovats1 = [22,25,28,29,31]
aprovats2 = [15,20,37,24,30]
aprovats3 = [20,12,22,30,25]
plt.scatter(cursos,aprovats1, color='yellow')
plt.scatter(cursos,aprovats2, color='red')
plt.scatter(cursos,aprovats3, color='green')
plt.xlabel('cursos')
plt.ylabel('aprovats i aprovades')
plt.show()

# %%
import pandas as pd
insurance_data = pd.read_csv('insurance.csv')
print(insurance_data.head(10))
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# 5   31  female  25.740         0     no  southeast   3756.62160
# 6   46  female  33.440         1     no  southeast   8240.58960
# 7   37  female  27.740         3     no  northwest   7281.50560
# 8   37    male  29.830         2     no  northeast   6406.41070
# 9   60  female  25.840         0     no  northwest  28923.13692

# %%
plt.scatter(insurance_data['bmi'], insurance_data['charges'],)
plt.xlabel('bmi')
plt.ylabel('charges')
plt.show()

# %%
import seaborn as sns
sns.scatterplot(x=insurance_data['bmi'], y=insurance_data['charges'])
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %%
sns.regplot(x=insurance_data['bmi'], y=insurance_data['charges'])
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %%
sns.scatterplot(x=insurance_data['bmi'], y=insurance_data['charges'], hue=insurance_data['smoker'])
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %%
sns.lmplot(x="bmi", y="charges", hue="smoker", data=insurance_data)

# %%
sns.swarmplot(x=insurance_data['smoker'], y=insurance_data['charges'])
# Out:
# /home/luis/.local/lib/python3.10/site-packages/seaborn/categorical.py:3399: UserWarning: 37.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='smoker', ylabel='charges'>
# /home/luis/.local/lib/python3.10/site-packages/seaborn/categorical.py:3399: UserWarning: 60.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x=insurance_data['region'], y=insurance_data['charges'])
# Out:
# /home/luis/.local/lib/python3.10/site-packages/seaborn/categorical.py:3399: UserWarning: 24.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/luis/.local/lib/python3.10/site-packages/seaborn/categorical.py:3399: UserWarning: 21.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/luis/.local/lib/python3.10/site-packages/seaborn/categorical.py:3399: UserWarning: 23.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/luis/.local/lib/python3.10/site-packages/seaborn/categorical.py:3399: UserWarning: 21.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='region', ylabel='charges'>
# /home/luis/.local/lib/python3.10/site-packages/seaborn/categorical.py:3399: UserWarning: 32.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/luis/.local/lib/python3.10/site-packages/seaborn/categorical.py:3399: UserWarning: 28.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/luis/.local/lib/python3.10/site-packages/seaborn/categorical.py:3399: UserWarning: 31.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/luis/.local/lib/python3.10/site-packages/seaborn/categorical.py:3399: UserWarning: 30.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x=insurance_data['region'],y=insurance_data['charges'], hue=insurance_data['smoker'])
# Out:
# /home/luis/.local/lib/python3.10/site-packages/seaborn/categorical.py:3399: UserWarning: 24.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/luis/.local/lib/python3.10/site-packages/seaborn/categorical.py:3399: UserWarning: 21.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/luis/.local/lib/python3.10/site-packages/seaborn/categorical.py:3399: UserWarning: 23.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/luis/.local/lib/python3.10/site-packages/seaborn/categorical.py:3399: UserWarning: 21.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='region', ylabel='charges'>
# /home/luis/.local/lib/python3.10/site-packages/seaborn/categorical.py:3399: UserWarning: 32.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/luis/.local/lib/python3.10/site-packages/seaborn/categorical.py:3399: UserWarning: 28.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/luis/.local/lib/python3.10/site-packages/seaborn/categorical.py:3399: UserWarning: 31.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/luis/.local/lib/python3.10/site-packages/seaborn/categorical.py:3399: UserWarning: 30.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
